# %%
import csv 
with open('D:\\Ineuron\\SQL\\SQL and python\\car.data','r')as f: 
      car_data=csv.reader(f,delimiter='\n') 
      for i in car_data: 
          print(i)
# Out:
# ['vhigh,vhigh,2,2,small,low,unacc']
# ['vhigh,vhigh,2,2,small,med,unacc']
# ['vhigh,vhigh,2,2,small,high,unacc']
# ['vhigh,vhigh,2,2,med,low,unacc']
# ['vhigh,vhigh,2,2,med,med,unacc']
# ['vhigh,vhigh,2,2,med,high,unacc']
# ['vhigh,vhigh,2,2,big,low,unacc']
# ['vhigh,vhigh,2,2,big,med,unacc']
# ['vhigh,vhigh,2,2,big,high,unacc']
# ['vhigh,vhigh,2,4,small,low,unacc']
# ['vhigh,vhigh,2,4,small,med,unacc']
# ['vhigh,vhigh,2,4,small,high,unacc']
# ['vhigh,vhigh,2,4,med,low,unacc']
# ['vhigh,vhigh,2,4,med,med,unacc']
# ['vhigh,vhigh,2,4,med,high,unacc']
# ['vhigh,vhigh,2,4,big,low,unacc']
# ['vhigh,vhigh,2,4,big,med,unacc']
# ['vhigh,vhigh,2,4,big,high,unacc']
# ['vhigh,vhigh,2,more,small,low,unacc']
# ['vhigh,vhigh,2,more,small,med,unacc']
# ['vhigh,vhigh,2,more,small,high,unacc']
# ['vhigh,vhigh,2,more,med,low,unacc']
# ['vhigh,vhigh,2,more,med,med,unacc']
# ['vhigh,vhigh,2,more,med,high,unacc']
# ['vhigh,vhigh,2,more,big,low,unacc']
# ['vhigh,vhigh,2,more,big,med,unacc']
# ...

# %%
# !pip install mysql-connector-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: You are using pip version 21.2.3; however, version 22.0.3 is available.
# You should consider upgrading via the 'C:\Program Files\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="sutapa"
)

print(mydb)

# %%
cursor = mydb.cursor()

# %%
cursor.execute("create database cardataset2")

# %%
cursor.execute("use cardataset2")

# %%
cursor.execute('create table cardataset2.car6(buying VARCHAR(30) ,maint VARCHAR(30)  ,doors VARCHAR(10) ,persons VARCHAR(30) ,lug_boot VARCHAR(30),safety VARCHAR(30),model varchar(30))')

# %%
cursor.execute(" show tables")

# %%
cursor.fetchall()
# Out:
# [('car6',)]

# %%
import csv 
 
with open('D:\\Ineuron\\SQL\\SQL and python\\car.data', 'r') as f: 
    data = csv.reader(f, delimiter='\n') 
    for row in data: 
        lst = row[0].split(',') 
        cursor.execute("INSERT INTO cardataset2.car6 values ('{0}', '{1}', '{2}', '{3}','{4}', '{5}', '{6}' )".format(lst[0], lst[1], lst[2], lst[3], lst[4], lst[5], lst[6]))

# %%
cursor.execute(" select * from car6")

# %%
cursor.fetchall()
# Out:
# [('vhigh', 'vhigh', '2', '2', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'big', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'big', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'big', 'med', 'unacc'),
# ...

# %%
cursor.execute('select count(*) from cardataset2.car6')

# %%
cursor.fetchall()
# Out:
# [(1728,)]

# %% [markdown]
# 6 . try to group all the data with COL1 AND count occurences of each and every record based on col1 value

# %%
cursor.execute('select count(*),buying from cardataset2.car6 group by buying')

# %%
cursor.fetchall()
# Out:
# [(432, 'vhigh'), (432, 'high'), (432, 'med'), (432, 'low')]

# %% [markdown]
# Try to filter a record where col 3 value will be 4 .

# %%
cursor.execute('select * from cardataset2.car6 where persons=4')

# %%
cursor.fetchall()
# Out:
# [('vhigh', 'vhigh', '2', '4', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'big', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'big', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '3', '4', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '3', '4', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '3', '4', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '3', '4', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '3', '4', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '3', '4', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '3', '4', 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '3', '4', 'big', 'med', 'unacc'),
# ...

# %%
query = "SELECT * FROM cardataset2.car6 WHERE doors = '4'"
cursor.execute(query)
cursor.fetchall()
# Out:
# [('vhigh', 'vhigh', '4', '2', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'big', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'big', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'big', 'med', 'unacc'),
# ...

# %% [markdown]
# 8.  Try to update a col 3 value with 8 whereever you have value equal to 2

# %%
query = "SELECT * FROM cardataset2.car6 WHERE doors = '8'"
cursor.execute(query)
cursor.fetchall()
# Out:
# []

# %%
query = "SELECT doors, count(*) FROM cardataset2.car6 GROUP BY doors"
cursor.execute(query)
cursor.fetchall()
# Out:
# [('2', 432), ('3', 432), ('4', 432), ('5more', 432)]

# %%
query = "UPDATE cardataset2.car6 SET doors = '8' WHERE doors = '2'"
cursor.execute(query)
mydb.commit()

# %%
query = "SELECT doors, count(*) FROM cardataset2.car6 GROUP BY doors"
cursor.execute(query)
cursor.fetchall()
# Out:
# [('8', 432), ('3', 432), ('4', 432), ('5more', 432)]

# %% [markdown]
# 9 . try to delete table

# %%
cursor.execute(" show databases")

# %%
cursor.fetchall()
# Out:
# [('cardataset',),
#  ('cardataset1',),
#  ('cardataset2',),
#  ('ineuron',),
#  ('ineuron_test',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sys',)]

# %%
cursor.execute("use cardataset")

# %%
cursor.execute(" show tables")

# %%
cursor.fetchall()
# Out:
# [('car',), ('car1',), ('car2',)]

# %%
query = "DROP TABLE car1"
cursor.execute(query)
mydb.commit()

# %%
query = "SHOW TABLES"
cursor.execute(query)
cursor.fetchall()
# Out:
# [('car',), ('car2',)]

# %%
query = "DROP DATABASE cardataset"
cursor.execute(query)
mydb.commit()

# %%
query = "SHOW DATABASES"
cursor.execute(query)
cursor.fetchall()
# Out:
# [('cardataset1',),
#  ('cardataset2',),
#  ('ineuron',),
#  ('ineuron_test',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sys',)]
